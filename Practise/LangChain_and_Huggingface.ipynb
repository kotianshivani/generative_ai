# %% [markdown]
# <a href="https://colab.research.google.com/github/kotianshivani/generative_ai/blob/main/Practise/LangChain_and_Huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#required libraries
# !pip install langchain-huggingface

##for api calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 10.5 MB/s eta 0:00:00
# ...

# %%
## Environment secret keys
from google.colab import userdata
sec_key = userdata.get('HF_TOKEN')
print(sec_key)
# Out:
# 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

# %%
##Huggingface endpoint
from langchain_huggingface import HuggingFaceEndpoint

# %%
## Environment secret keys
from google.colab import userdata
sec_key = userdata.get('HUGGINGFACEHUB_API_TOKEN')
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id=repo_id, model_kwargs = {"max_length":128},
    temperature=0.7,
    huggingfacehub_api_token=sec_key,
)

# %%
llm.invoke("What is machine learning?")
# Out:
# '\n\nMachine learning is a subfield of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform tasks without explicit programming. In other words, machine learning allows computers to learn from data and improve their performance on a specific task over time, without being explicitly programmed to do so.\n\nMachine learning algorithms are used in a wide variety of applications, including image and speech recognition, natural language processing, recommendation systems, and autonomous vehicles. These algorithms are designed to automatically learn patterns and relationships in data, and use that knowledge to make predictions or decisions about new, unseen data.\n\nMachine learning is a powerful tool for solving complex problems that would be difficult or impossible for humans to solve alone. It has the potential to revolutionize many industries and transform the way we live and work. However, it is important to 
# ...

# %%
from langchain import LLMChain
from langchain import PromptTemplate

question = "Who won the cricket world cup in the year 2011?"
template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] input_types={} partial_variables={} template="Question: {question}\n\nAnswer: Let's think step by step."

# %%
llm_chain = prompt | llm
print(llm_chain.invoke({"question": question}))
# Out:
# The 2011 Cricket World Cup was won by India. This is a historical event because India won their second World Cup in their home country, after the 1983 World Cup victory.
#
# Fun Fact: The final match of the 2011 World Cup was played at the Wankhede Stadium in Mumbai, where India defeated Sri Lanka by 6 wickets. The man of the match was the legendary Indian batsman, MS Dhoni.

# %% [markdown]
# HuggingFacePipeline

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer,max_new_tokens=100)
hf = HuggingFacePipeline(pipeline=pipeline)
# Out:
# Device set to use cpu

# %%
hf.invoke("What is machine learning?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'What is machine learning?\n\nIt is a basic, mathematical algorithm that is used to create a pattern, such as a word, or a combination or any kind of structure and then calculates a score for that pattern.\n\nThis mathematical algorithm is just called a "training network". It is supposed to provide you with the data needed to develop an appropriate training model.\n\n\nHow do I use it?\n\nA great resource on the subject is:\n\nhttps://gist.github.com/1l'
